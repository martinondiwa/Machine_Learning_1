# %%
import pandas as pd
import numpy as np
from sklearn import datasets 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

#turning on interactive mode on the scatter plot
#!pip install ipympl
#%matplotlib widget

# %%
wine = datasets.load_wine()

# %%
df = pd.DataFrame(wine["data"], columns=wine["feature_names"])
df["target"] = wine["target"]
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
#checking if you have missing value
df.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %% [markdown]
# ## Test Train split
# #splitting our values into training and testing datasets
# #ensure you import traintest split

# %%
x = df
y = x.pop("target")

# %%
x.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
#target removed so column numbers reduce
x.shape
# Out:
# (178, 13)

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
#Checking for unique classes of wine
y.unique()
# Out:
# array([0, 1, 2])

# %%
#Splitting our data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=55)

# %%
x_train.shape
# Out:
# (142, 13)

# %%
x_test.shape
# Out:
# (36, 13)

# %% [markdown]
# ## Train Classifier
# #import knn neighbors classifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
#Training our model
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Checking the accuracy of the model based on the test scores
knn.score(x_test, y_test)
# Out:
# 0.6388888888888888

# %% [markdown]
# ## Tunning Sensitivity of Model To ``n_neighbors``
# #At this stage import matplotlib to plot the outcome

# %%
k_range = range(1, 25)
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    scores.append(knn.score(x_test, y_test))

plt.figure()
plt.xlabel("k count")
plt.ylabel("Model Accuracy")
plt.scatter(k_range, scores)
plt.grid()
plt.xticks([0, 5, 10, 15, 20, 25, 30])
plt.show()

# %%
test_sizes = [0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
knn = KNeighborsClassifier(n_neighbors=5)

mean_scores = []  

for test_size in test_sizes:
    scores = []
    for i in range(1, 1000):
        x_train, x_test, y_train, y_test = train_test_split(
            x, y, test_size=1 - test_size
        )
        knn.fit(x_train, y_train)
        scores.append(knn.score(x_test, y_test))
    
    mean_scores.append(np.mean(scores))  
    

plt.figure()
plt.plot(test_sizes, mean_scores, marker='o', linestyle='None')


plt.xlabel("Training split %")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ## Make Predictions

# %%
prediction = knn.predict(x_test)

# %%
prediction
# Out:
# array([0, 1, 1, 1, 2, 0, 2, 1, 1, 0, 1, 1, 1, 1, 2, 0, 0, 2, 2, 0, 0, 1,
#        0, 2, 0, 1, 1, 0, 1, 2, 1, 1, 0, 2, 0, 0])

# %%
y_test
# Out:
# 168    2
# 80     1
# 124    1
# 97     1
# 25     0
# 35     0
# 62     1
# 159    2
# 72     1
# 78     1
# 164    2
# 153    2
# 106    1
# 65     1
# 87     1
# 38     0
# 39     0
# 148    2
# 165    2
# 31     0
# 53     0
# 128    1
# 34     0
# 154    2
# 8      0
# 63     1
# 143    2
# 13     0
# 117    1
# 136    2
# 113    1
# 121    1
# 73     1
# 133    2
# 16     0
# 42     0
# Name: target, dtype: int64

# %% [markdown]
# ## Using a confusion Matrix to Evaluate the efficiency of our Model
# #At this stage two imports are made:
#        #Confusion matrix
#        #Seaborn

# %%
cm = confusion_matrix(y_test, prediction)

# %%
cm
# Out:
# array([[10,  0,  1],
#        [ 2, 11,  2],
#        [ 1,  4,  5]])

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.ylabel("Truth")
plt.xlabel("Prediction")
plt.show()
